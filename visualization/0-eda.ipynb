# %% [markdown]
# data source : https://www.data.gouv.fr/fr/datasets/prix-maison-neuve-en-france/#_

# %%
import pandas as pd

# %%
url = 'https://static.data.gouv.fr/resources/prix-maison-neuve-en-france/20200617-110737/prix-maison-neuve-en-france.xlsx'

df = pd.read_excel(url)

# %%
df
# Out:
#     Unnamed: 0                                     Unnamed: 1  \
# 0          NaN              Prix des maisons neuves en France
# 1          NaN                                            NaN
# 2          NaN                                            NaN
# 3          NaN                                            NaN
# 4          NaN                                  PROFESSIONNEL
# 5          NaN                                     Architecte
# 6          NaN                Constructeur (CCMI-loi de 1990)
# 7          NaN                       Entrepreneur ou  artisan
# 8          NaN                           Particulier lui-même
# 9          NaN                                     Autres cas
# 10         NaN                               source: plans.fr
# 11         NaN                                            NaN
# 12         NaN  Faire construire sa maison : prix par régions
# 13         NaN                                            NaN
# ...
